# %% [markdown]
# # Bacis Print

# %%
print("Hello, Python")
print("Welcome to Jupyter Notebook")
print("I am .ipynb = Interactive Python Notebook")
# Out:
# Hello, Python
# Welcome to Jupyter Notebook
# I am .ipynb = Interactive Python Notebook
