# %% [markdown]
# ## Data Type ---> F. Digits Summation

# %%
'''https://codeforces.com/group/MWSDmqGsZm/contest/219158/problem/F'''
# Out:
# 'https://codeforces.com/group/MWSDmqGsZm/contest/219158/problem/F'

# %%
n, m = map(int, input().split())

summation = (n % 10) + (m % 10)

print(summation)
# Out:
#  10 55
# 5
